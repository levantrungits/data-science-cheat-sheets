# %% [markdown]
# ## Pandas 01

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Import Dataset

# %%
df = pd.read_csv("../data/chipotle.tsv", sep = "\t")

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %% [markdown]
# ### 2. Dataset Overview

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
list(df.columns)
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
df.describe()
# Out:
#           order_id     quantity
# count  4622.000000  4622.000000
# mean    927.254868     1.075725
# std     528.890796     0.410186
# min       1.000000     1.000000
# 25%     477.250000     1.000000
# 50%     926.000000     1.000000
# 75%    1393.000000     1.000000
# max    1834.000000    15.000000

# %%
df.describe(include = "all")
# Out:
#            order_id     quantity     item_name choice_description item_price
# count   4622.000000  4622.000000          4622               3376       4622
# unique          NaN          NaN            50               1043         78
# top             NaN          NaN  Chicken Bowl        [Diet Coke]     $8.75
# freq            NaN          NaN           726                134        730
# mean     927.254868     1.075725           NaN                NaN        NaN
# std      528.890796     0.410186           NaN                NaN        NaN
# min        1.000000     1.000000           NaN                NaN        NaN
# 25%      477.250000     1.000000           NaN                NaN        NaN
# 50%      926.000000     1.000000           NaN                NaN        NaN
# 75%     1393.000000     1.000000           NaN                NaN        NaN
# max     1834.000000    15.000000           NaN                NaN        NaN

# %% [markdown]
# ### 3. loc

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.loc[df.quantity == 15]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#      item_price
# 3598    $44.25

# %%
df.loc[(df.quantity == 2) & (df.item_name == "Nantucket Nectar")]
# Out:
#       order_id  quantity         item_name         choice_description  \
# 601        247         2  Nantucket Nectar  [Pineapple Orange Banana]
# 2379       947         2  Nantucket Nectar             [Peach Orange]
#
#      item_price
# 601      $6.78
# 2379     $6.78

# %%
df.loc[(df.quantity == 2) & (df.item_name == "Nantucket Nectar"), ['order_id', 'quantity', 'item_name']]
# Out:
#       order_id  quantity         item_name
# 601        247         2  Nantucket Nectar
# 2379       947         2  Nantucket Nectar

# %% [markdown]
# ### 4. iloc

# %%
df.iloc[9] # 9 is Index row
# Out:
# order_id                                                              5
# quantity                                                              1
# item_name                                                 Steak Burrito
# choice_description    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# item_price                                                       $9.25
# Name: 9, dtype: object

# %%
type(df.iloc[9]) # type is pandas.core.series.Series
# Out:
# pandas.core.series.Series

# %%
df.iloc[[9]] # type is pandas.core.frame.DataFrame
# Out:
#    order_id  quantity      item_name  \
# 9         5         1  Steak Burrito
#
#                                   choice_description item_price
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
df.iloc[3:11] # item row from 3 to 10 (up to 11)
# Out:
#     order_id  quantity                              item_name  \
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
#
#                                    choice_description item_price
# 3                                                 NaN     $2.39
# 4   [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5   [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                 NaN     $1.69
# 7   [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# ...

# %%
df.iloc[3:6, :-1] # not include lasted column.
# Out:
#    order_id  quantity                              item_name  \
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
#
#                                   choice_description
# 3                                                NaN
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...

# %%
df.iloc[3:6, -1] # lasted column only.
# Out:
# 3     $2.39
# 4    $16.98
# 5    $10.98
# Name: item_price, dtype: object

# %% [markdown]
# ### 5. Data manlipulation

# %%
df.item_price.dtype # dtype('O') is Python object
# Out:
# dtype('O')

# %% [markdown]
# #### Apply() function with lambda

# %%
df.item_price = df.item_price.apply(lambda x : float(x.replace('$', '')))

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
df['total_price'] = df['quantity'] * df['item_price']

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  total_price
# 0                                                NaN        2.39         2.39
# 1                                       [Clementine]        3.39         3.39
# 2                                            [Apple]        3.39         3.39
# 3                                                NaN        2.39         2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98        33.96

# %% [markdown]
# #### SUM()

# %%
total_rev = df['total_price'].sum()
print(total_rev)
# Out:
# 39237.02

# %% [markdown]
# GROUP BY

# %%
df.groupby('item_name')['quantity'].apply(print)
# Out:
# 298     1
# 341     1
# 357     1
# 388     1
# 417     1
# 553     1
# 639     1
# 721     1
# 743     1
# 879     1
# 1026    1
# 1051    1
# 1124    1
# 1167    1
# 1260    1
# 1279    1
# 1392    1
# 1755    1
# 1758    1
# 1849    1
# 1860    1
# 1916    1
# 1922    1
# 1937    1
# 1976    1
# 2108    1
# 2232    1
# 2374    1
# 2389    1
# 2713    1
# 2793    1
# 2860    1
# 3010    1
# 3132    1
# 3141    1
# 3389    2
# 3422    1
# 3600    1
# 3614    1
# 3633    1
# 3693    1
# 3766    1
# 3789    1
# 3806    1
# 3836    1
# 3875    1
# 3886    1
# 4169    1
# 4174    1
# 4359    1
# 4363    1
# 4522    1
# 4527    1
# 4535    1
# Name: 6 Pack Soft Drink, dtype: int64
# 39      1
# 58      1
# 95      1
# 115     1
# 127     1
#        ..
# 4380    1
# 4441    1
# 4485    1
# 4510    1
# 4594    1
# Name: Barbacoa Bowl, Length: 66, dtype: int64
# 21      1
# 81      1
# 121     1
# 130     1
# 144     1
#        ..
# 4355    1
# 4358    1
# 4592    1
# 4602    1
# 4603    1
# ...

# %%
c = df.groupby('item_name')['quantity'].sum()
c.sort_values(ascending=False).head(5)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Steak Burrito          386
# Canned Soft Drink      351
# Name: quantity, dtype: int64

# %% [markdown]
# #### Unique Value

# %%
df['item_name'].value_counts().count()
# Out:
# 50

# %%
df['item_name'].nunique()
# Out:
# 50
